# %% [markdown]
# # Group Activity 8
#
# The code author is Gaël Varoquaux

# %% [markdown]
# This example shows how to map our data into a lower dimensional space based on PCA.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D



from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

# centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()

# %%
def vis(X, y):
    '''this function visalize data in a 3D space'''
    fig = plt.figure(1, figsize=(4, 3))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

    # clear current plot
    plt.cla()

    for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
        ax.text3D(X[y == label, 0].mean(),
                  X[y == label, 1].mean() + 1.5,
                  X[y == label, 2].mean(), name,
                  horizontalalignment='center',
                  bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
    # Reorder the labels to have colors matching the cluster results
    y = np.choose(y, [1, 2, 0]).astype(np.float)
    ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
               edgecolor='k')

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])

    plt.show()

# %% [markdown]
# Preview data before dimensionality reduction.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

X = iris.data
y = iris.target


print(X[:5])
print(X.shape)
vis(X,y)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# (150, 4)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

X = iris.data
y = iris.target

# TODO
# PCA, three dimensionality

# Apply PCA to reduce to three dimensions
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)

# Visualize the data
def vis(X, y):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    scatter = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.get_cmap('viridis', 3))
    legend1 = ax.legend(*scatter.legend_elements(), title="Classes")
    ax.add_artist(legend1)
    plt.show()


vis(X,y)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

X = iris.data
y = iris.target

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# TODO PCA shrink to 2 dimensionality
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# TODO
# PC1 as x-axis, PC2 as y-axis, color is y
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=plt.cm.nipy_spectral)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset')
plt.colorbar()
plt.show()
