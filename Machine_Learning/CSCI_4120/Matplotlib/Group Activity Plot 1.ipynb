# %% [markdown]
# # Group Activity
# Finish the todo section

# %%
import pandas as pd
# TODO Import plot lib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df =  pd.read_csv('salary_vs_experience.csv', sep=',')
print(df[:5])
# Out:
#    ID  Years  Salary
# 0   1    1.0   39343
# 1   2    1.3   46205
# 2   3    1.5   37731
# 3   4    2.0   43525
# 4   5    2.2   39891

# %%
# TODO visualize years (x-axis) vs salary (y-axis) using a line chart
# you may need to check this website: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html 
# to learn how to get the data from a dataframe (df).
import pandas as pd
import matplotlib.pyplot as plt

x =df['Years']
y =df['Salary']
plt.plot(x, y)
plt.xlabel('Years')
plt.ylabel('Salary')
plt.title('Salary vs Years')
plt.show()
